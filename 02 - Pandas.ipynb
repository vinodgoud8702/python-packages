# %% [markdown]
# # Pandas

# %% [markdown]
# - Pandas is a Python library.
# -
# Pandas is used to analyze dat
#
# - Pandas is a powerful Python library designed specifically for data manipulation and analysis. It provides high-performance data structures and data analysis tools, making it a valuable tool for both data scientists and analysts.a.

# %% [markdown]
# ## Key Data Structures in Pandas

# %% [markdown]
# 1. __Series__: A one-dimensional labeled array capable of holding any data type (integers, floats, strings, objects, etc.).
#
# 2. __DataFrame__: A two-dimensional labeled data structure with columns that can hold different data types. It is similar to a spreadsheet.

# %% [markdown]
# ![image.png](attachment:36facca1-44b4-4210-9b62-333f2a62d2c2.png)

# %% [markdown]
# ## What is Pandas?

# %% [markdown]
# - Pandas is a Python library used for working with data sets.
#
# - It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# - The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.008.

# %% [markdown]
# ## Why Use Pandas?

# %% [markdown]
# - Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# - Pandas can clean messy data sets, and make them readable and relevant.
#
# - Relevant data is very important in data science.nce.

# %% [markdown]
# ## What Can Pandas Do?

# %% [markdown]
# Pandas gives you answers about the data. Like:
#
# - Is there a correlation between two or more columns?
#
# - What is average value?
#
# - Max value?
#
# - Min value?
#
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data. data.

# %% [markdown]
# ## Installation of Pandas

# %% [markdown]
# If you have Python and PIP already installed on a system, then installation of Pandas is very easy.

# %%
# !pip install pandas

# %% [markdown]
# ## Import Pandas

# %% [markdown]
# Once Pandas is installed, import it in your applications by adding the `import` keyword:

# %%
import pandas

# %% [markdown]
# ## Pandas as pd

# %% [markdown]
# - Pandas is usually imported under the `pd` alias.
#
# - __alias__: In Python alias are an alternate name for referring to the same thing.
#
# - Create an alias with the `as` keyword while importing:ing:

# %%
import pandas as pd

# %% [markdown]
# To load the pandas package and start working with it, import the package. The community agreed alias for pandas is `pd`, so loading pandas as `pd` is assumed standard practice for all of the pandas documentation.

# %% [markdown]
# ## Checking Pandas Version

# %% [markdown]
# The version string is stored under `__version__` attribute.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ## Pandas Data Table Representation

# %% [markdown]
# ![image.png](attachment:df099fec-69eb-4ab3-a22c-4a2d6f5468cc.png)

# %% [markdown]
# I want to store passenger data of the Titanic. For a number of passengers, I know the name (characters), age (integers) and sex (male/female) data.

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %% [markdown]
# To manually store data in a table, create a `DataFrame`. When using a Python dictionary of lists, the dictionary keys will be used as column headers and the values in each list as columns of the `DataFrame`.

# %% [markdown]
# A `DataFrame` is a 2-dimensional data structure that can store data of different types (including characters, integers, floating point values, categorical data and more) in columns. It is similar to a spreadsheet, a SQL table or the `data.frame` in R.
#
# - The table has 3 columns, each of them with a column label. The column labels are respectively `Name`, `Age` and `Sex`.
#
# - The column `Name` consists of textual data with each value a string, the column `Age` are numbers and the column `Sex` is textual data.a.

# %% [markdown]
# ## Each column in a `DataFrame` is a `Series`

# %% [markdown]
# ![image.png](attachment:ea7ffe03-337a-4be7-9125-1c41ae8a5686.png)

# %% [markdown]
# ## What is a Series?

# %% [markdown]
# - A Pandas Series is like a column in a table.
# -
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# ## Labels

# %% [markdown]
# - If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
# -
# This label can be used to access a specified value.

# %%
print(myvar[0])
# Out:
# 1

# %% [markdown]
# ##  Create Labels

# %% [markdown]
# - With the `index` argument, you can name your own labels.

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %% [markdown]
# When you have created labels, you can access an item by referring to the label.

# %%
print(myvar["y"])
# Out:
# 7

# %% [markdown]
# ## Key/Value Objects as Series

# %% [markdown]
# You can also use a key/value object, like a dictionary, when creating a Series.

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# - __Note__: The keys of the dictionary become the labels.

# %% [markdown]
# To select only some of the items in the dictionary, use the index argument and specify only the items you want to include in the Series.

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ## DataFrames

# %% [markdown]
# - Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
# -
# Series is like a column, a DataFrame is the whole table.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ## What is a DataFrame?

# %% [markdown]
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ## Locate Row

# %% [markdown]
# - As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# - Pandas use the `loc` attribute to return one or more specified row(s)s)

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %% [markdown]
# - __Note__: This example returns a Pandas Series.

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# - __Note__: When using `[]`, the result is a Pandas DataFrame.

# %% [markdown]
# ## Named Indexes

# %% [markdown]
# - With the `index` argument, you can name your own indexes.

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# ## Locate Named Indexes

# %% [markdown]
# - Use the named index in the `loc` attribute to return the specified row(s).

# %%
#refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [markdown]
# ## Read CSV Files

# %% [markdown]
# - A simple way to store big data sets is to use CSV files (comma separated files).
#
# - CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
#
# - In our examples we will be using a CSV file called 'data.csv'.sv'.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\devad\Downloads\data.csv")

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# - __Tip__: use `to_string()` to print the entire DataFrame.

# %% [markdown]
# If you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows:

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\devad\Downloads\data.csv")

print(df) 

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# ...

# %% [markdown]
# ## max_rows

# %% [markdown]
# - The number of rows returned is defined in Pandas option settings.
#
# - You can check your system's maximum rows with the `pd.options.display.max_rows` statement.t.

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# In my system the number is 60, which means that if the DataFrame contains more than 60 rows, the print(df) statement will return only the headers and the first and last 5 rows.
#
# You can change the maximum rows number with the same statement.

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv(r"C:\Users\devad\Downloads\data.csv")

df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Use read_csv() with the path to the CSV file to read a comma-separated values file
df = pd.read_csv(r"C:\Users\devad\Downloads\diabetes.csv")  #In parathesis you need to give path of dataset

# %% [markdown]
# ## Read JSON

# %% [markdown]
# - Big data sets are often stored, or extracted as JSON.
#
# - JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.
#
# - In our examples we will be using a JSON file called 'data.json'.on'.

# %%
import pandas as pd

df = pd.read_json(r"C:\Users\devad\Downloads\diabetes.json")

# %% [markdown]
# - __Tip__: use `to_string()` to print the entire DataFrame.

# %% [markdown]
# ## Dictionary as JSON

# %% [markdown]
# __JSON = Python Dictionary__
#
# JSON objects have the same format as Python dictionaries.

# %% [markdown]
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# ## Importing Excel files (single sheet)

# %%
#Reading excel files (both XLS and XLSX) is as easy as the read_excel() function, using the file path as an input.
df = pd.read_excel(r"C:\Users\devad\Downloads\diabetes.xlsx")

# %% [markdown]
# ## Importing text files

# %%
#you need to specify a separator with the sep argument, as shown below. 
# The separator argument refers to the symbol used to separate rows in a DataFrame. 
# Comma (sep = ","), whitespace(sep = "\s"), tab (sep = "\t"), and colon(sep = ":") are the commonly used separators.
# Here \s represents a single white space character.

df = pd.read_csv(r"C:\Users\devad\Downloads\diabetes.txt")

# %% [markdown]
# ## Example

# %%
#loading csv file 
df = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv") # r stands for "raw"
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## How do I select a subset of a DataFrame?

# %% [markdown]
# ![image.png](attachment:8d1cf4fa-b9fb-43a2-a7de-39064c83b8ff.png)

# %%
ages = df["Age"]

ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Viewing and understanding DataFrames using pandas

# %% [markdown]
# ## Viewing the Data

# %% [markdown]
# - One of the most used method for getting a quick overview of the DataFrame, is the `head()` method.
#
# - The `head()` method returns the headers and a specified number of rows, starting from the top.p.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# - __Note__: if the number of rows is not specified, the head() method will return the top 5 rows.

# %% [markdown]
# - There is also a `tail()` method for viewing the last rows of the DataFrame.
#
# - The `tail()` method returns the headers and a specified number of rows, starting from the bottom.m.

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# - In Pandas, the `describe()` method is used to generate descriptive statistics of a DataFrame or Series. It provides a quick overview of key summary statistics for numerical columns and, optionally, categorical columns.
#
# - By default, it only applies to numeric columns, but you can also use it for categorical data by passing `include='all'`.

# %%
# The .describe() method prints the summary statistics of all numeric columns, 
# such as count, mean, standard deviation, range, and quartiles of numeric columns.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Info About the Data

# %% [markdown]
# The DataFrames object has a method called `info()`, that gives you more information about the data set.

# %%
#The .info() method is a quick way to look at the data types, missing values, and data size of a DataFrame.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df.shape) # Get the number of rows and columns
print(df.shape[0]) # Get the number of rows only
print(df.shape[1]) # Get the number of columns only
# Out:
# (891, 12)
# 891
# 12

# %%
#Get all columns and column names
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#It can be converted to a list using a list() function
list(df.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ## Checking for missing values in pandas

# %% [markdown]
# ## Null Values

# %% [markdown]
# The `info()` method also tells us how many Non-Null values there are present in each column, and in our data set it seems like there are 164 of 169 Non-Null values in the "Calories" column.
#
# Which means that there are 5 rows with no value at all, in the "Calories" column, for whatever reason.
#
# Empty values, or Null values, can be bad when analyzing data, and you should consider removing rows with empty values. This is a step towards what is called cleaning data, and you will learn more about that in the next chapters.

# %%
df.isnull().head(10)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
# 5        False     False   False  False  False   True  False  False   False
# 6        False     False   False  False  False  False  False  False   False
# 7        False     False   False  False  False  False  False  False   False
# 8        False     False   False  False  False  False  False  False   False
# 9        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Slicing and Extracting Data in pandas

# %%
#Isolating one column using [ ] 
df['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
#Isolating two or more columns using [[ ]]
df[['Age', 'Fare']].head()
# Out:
#     Age     Fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
#Isolating one row using [ ]
df[df.index==2]
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
#Isolating two or more rows using [ ] 
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
df[df.index.isin(range(2,10))]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# ## Using .loc[] and .iloc[] to fetch rows

# %% [markdown]
# - In Pandas, `.loc[]` and `.iloc[]` are used for selecting rows (and columns) from a DataFrame, but they differ in how they refer to the data:

# %% [markdown]
# - `.loc[]`: Selects data by __label__ (i.e., based on row/column labels).
# - `.iloc[]`: Selects data by __position__ (i.e., based on integer index position).

# %% [markdown]
# ## Using `.loc[]`:

# %% [markdown]
# - Access rows and columns using labels.
#
# -  Syntax: `df.loc[row_label, column_label]`

# %%
df.loc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
import pandas as pd

data = {'Name': ['Deva', 'Sakku', 'Gopal'],
        'Age': [20, 21, 22],
        'City': ['NRT', 'SAP', 'VNK']}
data1 = pd.DataFrame(data, index=['A', 'B', 'C'])

print(data1.loc['B'])
# Out:
# Name    Sakku
# Age        21
# City      SAP
# Name: B, dtype: object

# %%
print(data1.loc[['A', 'C']])
# Out:
#     Name  Age City
# A   Deva   20  NRT
# C  Gopal   22  VNK

# %%
print(data1.loc['A', ['Name', 'City']])
# Out:
# Name    Deva
# City     NRT
# Name: A, dtype: object

# %% [markdown]
# ## Using `.iloc[]`:

# %% [markdown]
# - Access rows and columns using integer index positions.
#
# - Syntax: `df.iloc[row_position, column_position]`

# %%
print(data1.iloc[0])
# Out:
# Name    Deva
# Age       20
# City     NRT
# Name: A, dtype: object

# %%
print(data1.iloc[[0, 2]])
# Out:
#     Name  Age City
# A   Deva   20  NRT
# C  Gopal   22  VNK

# %%
print(data1.iloc[1, [0, 2]])
# Out:
# Name    Sakku
# City      SAP
# Name: B, dtype: object

# %%
df.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
#you can also fetch multiple rows by providing a range in square brackets.
df.iloc[2:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
df.loc[2:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# # Cleaning data using pandas

# %% [markdown]
# - Data cleaning is one of the most common tasks in data science.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# - Empty cells
#
# - Data in wrong format
#
# - Wrong data
#
# - Duplicates
#   of them.

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Survived'])

# %%
data.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
# finding the null values and sum them together 
data.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %% [markdown]
# ## Dealing with missing data technique

# %% [markdown]
# ## 1. Dropping missing values

# %% [markdown]
# ### Remove Rows

# %% [markdown]
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
data1 = data.dropna()

# %% [markdown]
# __Note__: By default, the `dropna()` method returns a new DataFrame, and will not change the original.

# %%
# finding the null values after the dropna() method
data1.isnull().sum()
# Out:
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Survived'])

# %% [markdown]
# If you want to change the original DataFrame, use the `inplace = True` argument:

# %%
data.dropna(inplace=True, axis=0)
print(data.head())
print(data.isnull().sum())
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500
# Survived    0
# Age         0
# Fare        0
# dtype: int64

# %% [markdown]
# - __Note__: Now, the `dropna(inplace = True)` will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.

# %% [markdown]
# ## 2. Replacing missing values

# %% [markdown]
# - Another way of dealing with empty cells is to insert a new value instead.
#
# - This way you do not have to delete entire rows just because of some empty cells.
#
# - The `fillna()` method allows us to replace empty cells with a value:lue:

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv")

data["Age"] = data["Age"].fillna(130)

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male   35.0      0
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Replace Only For Specified Columns

# %% [markdown]
# The example above replaces all empty cells in the whole Data Frame.
#
# To only replace empty values for one column, specify the column name for the DataFrame:

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv")

data["Cabin"] = data["Cabin"].fillna(130)

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Survived'])

# %%
data.head(12)
# Out:
#     Survived   Age     Fare
# 0          0  22.0   7.2500
# 1          1  38.0  71.2833
# 2          1  26.0   7.9250
# 3          1  35.0  53.1000
# 4          0  35.0   8.0500
# 5          0   NaN   8.4583
# 6          0  54.0  51.8625
# 7          0   2.0  21.0750
# 8          1  27.0  11.1333
# 9          1  14.0  30.0708
# 10         1   4.0  16.7000
# 11         1  58.0  26.5500

# %% [markdown]
# ## Replace Using Mean, Median, or Mode

# %% [markdown]
# - A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# - Pandas uses the `mean()` `median()` and `mode()` methods to calculate the respective values for a specified column:n:

# %% [markdown]
# - __Mean__ = the average value (the sum of all values divided by number of values).

# %%
#replacing the NAN value usinf mean()
mean_value = data['Age'].mean()
print(mean_value)
# Out:
# 29.69911764705882

# %%
data3 = data.fillna(mean_value)

# %%
data3.head(12)
# Out:
#     Survived        Age     Fare
# 0          0  22.000000   7.2500
# 1          1  38.000000  71.2833
# 2          1  26.000000   7.9250
# 3          1  35.000000  53.1000
# 4          0  35.000000   8.0500
# 5          0  29.699118   8.4583
# 6          0  54.000000  51.8625
# 7          0   2.000000  21.0750
# 8          1  27.000000  11.1333
# 9          1  14.000000  30.0708
# 10         1   4.000000  16.7000
# 11         1  58.000000  26.5500

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Survived'])
data.head(12)
# Out:
#     Survived   Age     Fare
# 0          0  22.0   7.2500
# 1          1  38.0  71.2833
# 2          1  26.0   7.9250
# 3          1  35.0  53.1000
# 4          0  35.0   8.0500
# 5          0   NaN   8.4583
# 6          0  54.0  51.8625
# 7          0   2.0  21.0750
# 8          1  27.0  11.1333
# 9          1  14.0  30.0708
# 10         1   4.0  16.7000
# 11         1  58.0  26.5500

# %% [markdown]
# - __Median__ = the value in the middle, after you have sorted all values ascending.

# %%
#replacing the NAN value usinf median()
median_value =data['Age'].median()
data4 = data.fillna(median_value)
print(median_value)
# Out:
# 28.0

# %%
data4.head(12)
# Out:
#     Survived   Age     Fare
# 0          0  22.0   7.2500
# 1          1  38.0  71.2833
# 2          1  26.0   7.9250
# 3          1  35.0  53.1000
# 4          0  35.0   8.0500
# 5          0  28.0   8.4583
# 6          0  54.0  51.8625
# 7          0   2.0  21.0750
# 8          1  27.0  11.1333
# 9          1  14.0  30.0708
# 10         1   4.0  16.7000
# 11         1  58.0  26.5500

# %% [markdown]
# - __Mode__ = the value that appears most frequently.

# %%
#replacing the NAN value usinf mode()
mode_value =data['Age'].mode()[0]
data5 = data.fillna(mode_value)
print(mode_value)
# Out:
# 24.0

# %%
data5.head(12)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ## 3.Duplicate Data

# %% [markdown]
# - To discover duplicates, we can use the `duplicated()` method.
#
# - The `duplicated()` method returns a Boolean values for each row:w:

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Survived'])
data.head(12)
# Out:
#     Survived   Age     Fare
# 0          0  22.0   7.2500
# 1          1  38.0  71.2833
# 2          1  26.0   7.9250
# 3          1  35.0  53.1000
# 4          0  35.0   8.0500
# 5          0   NaN   8.4583
# 6          0  54.0  51.8625
# 7          0   2.0  21.0750
# 8          1  27.0  11.1333
# 9          1  14.0  30.0708
# 10         1   4.0  16.7000
# 11         1  58.0  26.5500

# %%
print(data.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# ## Removing Duplicates

# %% [markdown]
# To remove duplicates, use the `drop_duplicates()` method.

# %%
#shape of dataset
data.shape
# Out:
# (891, 3)

# %%
data5 = data.drop_duplicates()
data5.shape
# Out:
# (745, 3)

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# - __Remember__: The `(inplace = True)` will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame.

# %% [markdown]
# ## Data Correlations

# %% [markdown]
# ### Finding Relationships

# %% [markdown]
# A great aspect of the Pandas module is the `corr()` method.
#
# The `corr()` method calculates the relationship between each column in your data set.sv'.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\devad\Downloads\data (1).csv")

print(df.corr())
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# - __Note__: The `corr()` method ignores "not numeric" columns.

# %% [markdown]
# ## Result Explained

# %% [markdown]
# The Result of the `corr()` method is a table with a lot of numbers that represents how well the relationship is between two columns.
#
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

# %% [markdown]
# - __What is a good correlation?__ It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.

# %% [markdown]
# ## Perfect Correlation:

# %% [markdown]
# We can see that "Duration" and "Duration" got the number `1.000000`, which makes sense, each column always has a perfect relationship with itself.

# %% [markdown]
# ## Good Correlation:

# %% [markdown]
# "Duration" and "Calories" got a `0.922721` correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out.

# %% [markdown]
# ## Bad Correlation:

# %% [markdown]
# "Duration" and "Maxpulse" got a `0.009403` correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa.

# %% [markdown]
# ## Renaming columns

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Survived'])
data.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
# renaming the column name
data.rename(columns = {'Age':'New_Age'}, inplace = True)
data.head()
# Out:
#    Survived  New_Age     Fare
# 0         0     22.0   7.2500
# 1         1     38.0  71.2833
# 2         1     26.0   7.9250
# 3         1     35.0  53.1000
# 4         0     35.0   8.0500

# %% [markdown]
# ## Data analysis in pandas

# %%
#Summary operators (mean, mode, median)

# %%
#you can get the mean of each column value using the .mean() method.
data.mean()
# Out:
# Survived     0.383838
# New_Age     29.699118
# Fare        32.204208
# dtype: float64

# %%
#A mode can be computed similarly using the .mode() method. 
data.mode()
# Out:
#    Survived  New_Age  Fare
# 0         0     24.0  8.05

# %%
#the median of each column is computed with the .median() method
data.median()
# Out:
# Survived     0.0000
# New_Age     28.0000
# Fare        14.4542
# dtype: float64

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## Aggregating data with .groupby() in pandas

# %% [markdown]
# - You can do that by combining the .groupby() method with a summary method of your choice.
#
# -
# when you going to apply groupby() you need to clean the data

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\titanic.csv", usecols =['Age','Fare','Cabin','Survived'])
data.head()
# Out:
#    Survived   Age     Fare Cabin
# 0         0  22.0   7.2500   NaN
# 1         1  38.0  71.2833   C85
# 2         1  26.0   7.9250   NaN
# 3         1  35.0  53.1000  C123
# 4         0  35.0   8.0500   NaN

# %%
mean_value = data['Age'].mean()
print(mean_value)
# Out:
# 29.69911764705882

# %%
data.fillna(mean_value).head()
# Out:
#    Survived   Age     Fare      Cabin
# 0         0  22.0   7.2500  29.699118
# 1         1  38.0  71.2833        C85
# 2         1  26.0   7.9250  29.699118
# 3         1  35.0  53.1000       C123
# 4         0  35.0   8.0500  29.699118

# %%
data.groupby('Cabin').mean().head()
# Out:
#        Survived   Age     Fare
# Cabin
# A10         0.0  36.0  40.1250
# A14         0.0   NaN  52.0000
# A16         1.0  48.0  39.6000
# A19         0.0   NaN  26.0000
# A20         1.0  49.0  56.9292
